# %% [markdown]
# ## Sentiment Analysis for Movie Reviews

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
X_train = train_data['review_text']
y_train = train_data['class_index']
X_test = test_data['review_text']
y_test = test_data['class_index']

# %%
vectorizer = CountVectorizer()
X_train_counts = vectorizer.fit_transform(X_train)
X_test_counts = vectorizer.transform(X_test)

# %%
classifier = MultinomialNB()
classifier.fit(X_train_counts, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = classifier.predict(X_test_counts)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6355763883371732
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.18      0.25       928
#            1       0.50      0.43      0.46      4141
#            2       0.71      0.82      0.76     13896
#            3       0.53      0.48      0.51      5029
#            4       0.47      0.24      0.32      1180
#
#     accuracy                           0.64     25174
#    macro avg       0.53      0.43      0.46     25174
# weighted avg       0.62      0.64      0.62     25174

# %% [markdown]
# #### COMPLETE ANALYSIS OF THE CODE

# %% [markdown]
# We load data set from the CSV files (train.csv and test.csv). <br>
# We separate the dataset into features and targets (X_train, X_test and y_train, y_test).<br>
# We implement CountVectorizer for the text data tokenization and token-by-token counting resulting in a matrix.<br>
# We fit a "Naive Bayes classifier (MultinomialNB)" on the training data.<br>
# We use the already trained classifier for the prediction of the labels for the testing set.<br>
# The performance of the classifier is encoded by the function of accuracy and creating a classification report.<br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
train_data = pd.read_csv("train.csv")
sentiment_distribution = train_data['class_index'].value_counts().sort_index()
plt.bar(sentiment_distribution.index, sentiment_distribution.values)
plt.xlabel('Sentiment Label')
plt.ylabel('Number of Sentences')
plt.title('Distribution of Sentiment Labels')
plt.xticks(sentiment_distribution.index)
plt.show()
